# %%
Sys.setenv(RETICULATE_PYTHON = "/Users/george/.virtualenvs/venv/bin/python")
options(reticulate.trace = TRUE)
library(picsure)

# %%
token_file <- "token.txt"
token <- scan(token_file, what = "character")

bdc <- picsure::connect(
    platform = "BDC_DEV_Authorized",
    token = token
)
