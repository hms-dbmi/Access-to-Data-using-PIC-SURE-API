# %% [markdown]
# # *NHLBI BioData Catalyst® (BDC) Powered by PIC-SURE* API use-case: quick analysis on Hematopoietic Cell Transplant for Sickle Cell Disease (HCT for SCD) data

# %% [markdown]
# For a more basic introduction to the python PIC-SURE API, see the `1_PICSURE_API_101.ipynb` notebook.
#
# **Before running this notebook, please be sure to review the "Get your security token" documentation, which exists in the [`README.md` file](../README.md). It explains how to get a security token, which is mandatory to use the PIC-SURE API.**
#
# To set up your token file, be sure to run the [`Workspace_setup.ipynb` file](./Workspace_setup.ipynb).

# %% [markdown]
#  -------

# %% [markdown]
# ## Environment set-up
#
# ### Pre-requisites
# * python 3.10.20 or later
# * pip python package manager, already available in most systems with a python interpreter installed (link to pip)
#
# ### Install packages
#
# **Note that if you are using the dedicated PIC-SURE environment within the *BDC Powered by Seven Bridges* platform, the necessary packages have already been installed.**

# %%
import sys
import pandas as pd
# pip install matplotlib
import matplotlib.pyplot as plt

# %%
# !{sys.executable} -m pip install --upgrade --force-reinstall git+https://github.com/hms-dbmi/pic-sure-python-adapter-hpds.git@main

# %%
import picsure

# %% [markdown]
# ##### Set the display parameters for tables and plots

# %%
# Pandas DataFrame display options
pd.set_option("display.max_rows", 100)

# Matplotlib parameters options
fig_size = plt.rcParams["figure.figsize"]
 
# Prints: [8.0, 6.0]
fig_size[0] = 14
fig_size[1] = 8
plt.rcParams["figure.figsize"] = fig_size

font = {'weight' : 'bold',
        'size'   : 14}

plt.rc('font', **font)

# %% [markdown]
# ## Connecting to the PIC-SURE network

# %%
token_file = "token.txt"

with open(token_file, "r") as f:
    my_token = f.read()

session = picsure.connect(picsure.Platform.BDC_AUTHORIZED, my_token)

# %% [markdown]
# # Analysis on Hematopoietic Cell Transplant for Sickle Cell Disease (HCT for SCD) data

# %% [markdown]
# Let's search the data dictionary in PIC-SURE to find all the variables in the `HCT for SCD` study, which is associated to PHS study number `phs002385`.

# %%
scd_dataframe = session.searchDictionary("phs002385")
print(scd_dataframe.shape)
scd_dataframe.head()

# %% [markdown]
# ## Building a query: investigating male patients with avascular necrosis who received their transplant after 1999

# %% [markdown]
# If you are interested in learning more about the available query methods, see the `1_PICSURE_API_101.ipynb` notebook.

# %% [markdown]
# Let's say we are interested in the age at which patients from the following cohort received their transplant:
#
# - males
# - patients with avascular necrosis
# - patients who received their transplant after 1999
#
# We will use regular expressions to search the variable descriptions within the HCT for SCD study to find these variables.

# %%
scd_dataframe[scd_dataframe.description.str.contains("Sex|Avascular necrosis|Year of transplant$")]

sex_var = scd_dataframe[scd_dataframe.description.str.contains("Sex")][["conceptPath"]].iloc[0, 0]
necrosis_var = scd_dataframe[scd_dataframe.description.str.contains("Avascular necrosis")][["conceptPath"]].iloc[0, 0]
transplant_var = scd_dataframe[scd_dataframe.description.str.contains("Year of transplant$")][["conceptPath"]].iloc[0, 0]

# %% [markdown]
# Now we can create a new query using the `conceptPath` associated with our variables of interest and apply our filters to retrieve the cohort of interest.

# %% [markdown]
# We are also interested in the patients' age at which they received their transplant. However, we do not want to filter our cohort based on these values. We can use the `includeConcepts` parameter to add this variable to the query output without filtering.
#
# Using this cohort, we can add the variable of interest: "Patient age at transplant, years"

# %%
age_at_transplant = scd_dataframe[scd_dataframe.description.str.contains("age at transplant, years$")][["conceptPath"]].iloc[0, 0]

# Build filter clauses
sex_clause        = picsure.buildClause(sex_var, picsure.PhenotypicFilterType.FILTER, categories="Male")
necrosis_clause   = picsure.buildClause(necrosis_var, picsure.PhenotypicFilterType.FILTER, categories="Yes")
transplant_clause = picsure.buildClause(transplant_var, picsure.PhenotypicFilterType.FILTER, min=1999)

# Combine filters with AND logic
filter_tree = picsure.buildClauseGroup([sex_clause, necrosis_clause, transplant_clause], operator=picsure.GroupOperator.AND)

# Build query: filter rows, include age column in output
myquery = picsure.buildQuery(phenotypicFilter=filter_tree, includeConcepts=[age_at_transplant])
results = session.runQuery(myquery, type=picsure.QueryType.PARTICIPANT)

# %% [markdown]
# Once our query object is built and run, the results are returned as a DataFrame.

# %%
results.head()

# %% [markdown]
# Once the data has been retrieved as a dataframe, you can use python functions to conduct analyses and create visualizations, such as this:

# %%
results[age_at_transplant].plot.hist(legend=None, 
                                      title= "Age when transplant received in males with avascular necrosis from 2000 to present", 
                                      bins=15)
