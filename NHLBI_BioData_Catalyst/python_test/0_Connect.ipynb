# %%
pip install --upgrade --force-reinstall git+https://github.com/hms-dbmi/pic-sure-python-adapter-hpds.git@main
# Out:
# Collecting git+https://github.com/hms-dbmi/pic-sure-python-adapter-hpds.git@main
#   Cloning https://github.com/hms-dbmi/pic-sure-python-adapter-hpds.git (to revision main) to /private/var/folders/n3/wd1bprj14gjf3l0y580nx2z40000gq/T/pip-req-build-tl15089b
#   Running command git clone --filter=blob:none --quiet https://github.com/hms-dbmi/pic-sure-python-adapter-hpds.git /private/var/folders/n3/wd1bprj14gjf3l0y580nx2z40000gq/T/pip-req-build-tl15089b
#   Running command git checkout -b main --track origin/main
#   Switched to a new branch 'main'
#   branch 'main' set up to track 'origin/main'.
#   Resolved https://github.com/hms-dbmi/pic-sure-python-adapter-hpds.git to commit 28e9ab3111b728035ebd9716801ff9d1a9be5b8a
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting httpx>=0.27 (from picsure==0.1.0)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting pandas>=2.0 (from picsure==0.1.0)
#   Using cached pandas-3.0.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (79 kB)
# Collecting anyio (from httpx>=0.27->picsure==0.1.0)
#   Using cached anyio-4.13.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting certifi (from httpx>=0.27->picsure==0.1.0)
#   Using cached certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx>=0.27->picsure==0.1.0)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx>=0.27->picsure==0.1.0)
#   Using cached idna-3.12-py3-none-any.whl.metadata (8.0 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx>=0.27->picsure==0.1.0)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting numpy>=1.26.0 (from pandas>=2.0->picsure==0.1.0)
#   Using cached numpy-2.4.4-cp311-cp311-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Collecting python-dateutil>=2.8.2 (from pandas>=2.0->picsure==0.1.0)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas>=2.0->picsure==0.1.0)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting typing_extensions>=4.5 (from anyio->httpx>=0.27->picsure==0.1.0)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached pandas-3.0.2-cp311-cp311-macosx_11_0_arm64.whl (9.9 MB)
# Using cached numpy-2.4.4-cp311-cp311-macosx_14_0_arm64.whl (5.5 MB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Using cached anyio-4.13.0-py3-none-any.whl (114 kB)
# Using cached idna-3.12-py3-none-any.whl (68 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached certifi-2026.2.25-py3-none-any.whl (153 kB)
# Building wheels for collected packages: picsure
#   Building wheel for picsure (pyproject.toml) ... done
#   Created wheel for picsure: filename=picsure-0.1.0-py3-none-any.whl size=31253 sha256=6076a1ccd1f965a2eb058359ab54263063eb25fae03eec66390d02e73aa22665
#   Stored in directory: /private/var/folders/n3/wd1bprj14gjf3l0y580nx2z40000gq/T/pip-ephem-wheel-cache-tc603272/wheels/5b/5f/97/e7864a47e28aaf9d463ca212b6f2aa6fff8256e5e05bebd2e3
# Successfully built picsure
# Installing collected packages: typing_extensions, six, numpy, idna, h11, certifi, python-dateutil, httpcore, anyio, pandas, httpx, picsure
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.15.0
#     Uninstalling typing_extensions-4.15.0:
#       Successfully uninstalled typing_extensions-4.15.032m 0/12 [typing_extensions]
#   Attempting uninstall: six━━━━━━━━━━━━━━━━━  0/12 [typing_extensions]
#     Found existing installation: six 1.17.0━  0/12 [typing_extensions]
#     Uninstalling six-1.17.0:━━━━━━━━━━━━━━━━  0/12 [typing_extensions]
#       Successfully uninstalled six-1.17.0━━━  0/12 [typing_extensions]
#   Attempting uninstall: numpym━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/12 [six]
#     Found existing installation: numpy 2.4.4━━━━━━━━━━━━━━━━━━  1/12 [six]
#     Uninstalling numpy-2.4.4:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/12 [six]
#       Successfully uninstalled numpy-2.4.4━━━━━━━━━━━━━━━━━━━━  1/12 [six]
#   Attempting uninstall: idna━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/12 [numpy]
#     Found existing installation: idna 3.12━━━━━━━━━━━━━━━━━━━━  2/12 [numpy]
#     Uninstalling idna-3.12:0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/12 [numpy]
#       Successfully uninstalled idna-3.12━━━━━━━━━━━━━━━━━━━━━━  2/12 [numpy]
#   Attempting uninstall: h110m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/12 [numpy]
#     Found existing installation: h11 0.16.0━━━━━━━━━━━━━━━━━━━  2/12 [numpy]
#     Uninstalling h11-0.16.0:m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/12 [numpy]
#       Successfully uninstalled h11-0.16.0━━━━━━━━━━━━━━━━━━━━━  2/12 [numpy]
#   Attempting uninstall: certifi━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/12 [numpy]
#     Found existing installation: certifi 2026.2.25━━━━━━━━━━━━  2/12 [numpy]
#     Uninstalling certifi-2026.2.25:━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/12 [numpy]
#       Successfully uninstalled certifi-2026.2.25━━━━━━━━━━━━━━  2/12 [numpy]
#   Attempting uninstall: python-dateutil━━━━━━━━━━━━━━━━━━━━━━━  2/12 [numpy]
#     Found existing installation: python-dateutil 2.9.0.post0━━  2/12 [numpy]
#     Uninstalling python-dateutil-2.9.0.post0:━━━━━━━━━━━━━━━━━  2/12 [numpy]
#       Successfully uninstalled python-dateutil-2.9.0.post0━━━━  2/12 [numpy]
#   Attempting uninstall: httpcore━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/12 [numpy]
#     Found existing installation: httpcore 1.0.9━━━━━━━━━━━━━━━  2/12 [numpy]
#     Uninstalling httpcore-1.0.9:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/12 [numpy]
#       Successfully uninstalled httpcore-1.0.9━━━━━━━━━━━━━━━━━  2/12 [numpy]
#   Attempting uninstall: anyio━━╺━━━━━━━━━━━━━━━━  7/12 [httpcore]
#     Found existing installation: anyio 4.13.0m━━━━━━━━━━━━━━━━  7/12 [httpcore]
#     Uninstalling anyio-4.13.0:m╺━━━━━━━━━━━━━━━━  7/12 [httpcore]
#       Successfully uninstalled anyio-4.13.090m━━━━━━━━━━━━━━━━  7/12 [httpcore]
#   Attempting uninstall: pandasm╺━━━━━━━━━━━━━━━━  7/12 [httpcore]
#     Found existing installation: pandas 3.0.2m━━━━━━━━━━━━━━━━  7/12 [httpcore]
#     Uninstalling pandas-3.0.2:m╺━━━━━━━━━━━━━━━━  7/12 [httpcore]
#       Successfully uninstalled pandas-3.0.290m━━━━━━━━━━━━━━━━  7/12 [httpcore]
#   Attempting uninstall: httpx━━━━━━━━━╺━━━━━━━━━  9/12 [pandas]
#     Found existing installation: httpx 0.28.1━━━━━━━━━  9/12 [pandas]
#     Uninstalling httpx-0.28.1:━━━━╺━━━━━━━━━  9/12 [pandas]
#       Successfully uninstalled httpx-0.28.1╺━━━━━━━━━  9/12 [pandas]
#   Attempting uninstall: picsure━━━╺━━━━━━━━━  9/12 [pandas]
#     Found existing installation: picsure 0.1.00m━━━━━━━━━  9/12 [pandas]
#     Uninstalling picsure-0.1.0:━━━╺━━━━━━━━━  9/12 [pandas]
#       Successfully uninstalled picsure-0.1.0━━━━━━━━━  9/12 [pandas]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12/12 [picsure] [pandas]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scipy 1.14.1 requires numpy<2.3,>=1.23.5, but you have numpy 2.4.4 which is incompatible.
# Successfully installed anyio-4.13.0 certifi-2026.2.25 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.12 numpy-2.4.4 pandas-3.0.2 picsure-0.1.0 python-dateutil-2.9.0.post0 six-1.17.0 typing_extensions-4.15.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import picsure

# %%
token_file = "token.txt"

with open(token_file, "r") as f:
    my_token = f.read()

# %%
authorized_session = picsure.connect(
    picsure.Platform.BDC_DEV_AUTHORIZED,
    my_token
)
# Out:
# You're successfully connected to BDC Authorized as user george_colon@hms.harvard.edu!
# Your token expires on unknown.

# %%
open_session = picsure.connect(
    picsure.Platform.BDC_DEV_OPEN
)
# Out:
# You're successfully connected to BDC Open (open access).

# %%
nhanes_open = picsure.connect(
    picsure.Platform.NHANES_OPEN
)
# Out:
# You're successfully connected to Nhanes Open (open access).
