# %%
pip install --upgrade --force-reinstall git+https://github.com/hms-dbmi/pic-sure-python-adapter-hpds.git@main
# Out:
# Collecting git+https://github.com/hms-dbmi/pic-sure-python-adapter-hpds.git@main
#   Cloning https://github.com/hms-dbmi/pic-sure-python-adapter-hpds.git (to revision main) to /private/var/folders/n3/wd1bprj14gjf3l0y580nx2z40000gq/T/pip-req-build-5w628dmi
#   Running command git clone --filter=blob:none --quiet https://github.com/hms-dbmi/pic-sure-python-adapter-hpds.git /private/var/folders/n3/wd1bprj14gjf3l0y580nx2z40000gq/T/pip-req-build-5w628dmi
#   Running command git checkout -b main --track origin/main
#   Switched to a new branch 'main'
#   branch 'main' set up to track 'origin/main'.
#   Resolved https://github.com/hms-dbmi/pic-sure-python-adapter-hpds.git to commit a973094f83ce42e1a715a3f87f5c434213ef46f6
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting httpx<1,>=0.27 (from picsure==0.1.0)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting pandas<3,>=2 (from picsure==0.1.0)
#   Using cached pandas-2.3.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (91 kB)
# Collecting anyio (from httpx<1,>=0.27->picsure==0.1.0)
#   Using cached anyio-4.13.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting certifi (from httpx<1,>=0.27->picsure==0.1.0)
#   Using cached certifi-2026.4.22-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.27->picsure==0.1.0)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx<1,>=0.27->picsure==0.1.0)
#   Using cached idna-3.13-py3-none-any.whl.metadata (8.0 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.27->picsure==0.1.0)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting numpy>=1.23.2 (from pandas<3,>=2->picsure==0.1.0)
#   Using cached numpy-2.4.4-cp311-cp311-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Collecting python-dateutil>=2.8.2 (from pandas<3,>=2->picsure==0.1.0)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas<3,>=2->picsure==0.1.0)
#   Using cached pytz-2026.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas<3,>=2->picsure==0.1.0)
#   Using cached tzdata-2026.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas<3,>=2->picsure==0.1.0)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting typing_extensions>=4.5 (from anyio->httpx<1,>=0.27->picsure==0.1.0)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached pandas-2.3.3-cp311-cp311-macosx_11_0_arm64.whl (10.8 MB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached numpy-2.4.4-cp311-cp311-macosx_14_0_arm64.whl (5.5 MB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached pytz-2026.2-py2.py3-none-any.whl (510 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Using cached tzdata-2026.2-py2.py3-none-any.whl (349 kB)
# Using cached anyio-4.13.0-py3-none-any.whl (114 kB)
# Using cached idna-3.13-py3-none-any.whl (68 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached certifi-2026.4.22-py3-none-any.whl (135 kB)
# Building wheels for collected packages: picsure
#   Building wheel for picsure (pyproject.toml) ... done
#   Created wheel for picsure: filename=picsure-0.1.0-py3-none-any.whl size=48331 sha256=86f3ef3f7e72d50fedd21e71b146f8f55b560684d3b80b05f30c8dd5104be797
#   Stored in directory: /private/var/folders/n3/wd1bprj14gjf3l0y580nx2z40000gq/T/pip-ephem-wheel-cache-kl_a2cp4/wheels/5b/5f/97/e7864a47e28aaf9d463ca212b6f2aa6fff8256e5e05bebd2e3
# Successfully built picsure
# Installing collected packages: pytz, tzdata, typing_extensions, six, numpy, idna, h11, certifi, python-dateutil, httpcore, anyio, pandas, httpx, picsure
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2026.1.post1
#     Uninstalling pytz-2026.1.post1:
#       Successfully uninstalled pytz-2026.1.post1
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2026.2
#     Uninstalling tzdata-2026.2:
#       Successfully uninstalled tzdata-2026.2
#   Attempting uninstall: typing_extensions━━━━━━━━━━━━━━━━━━━━━━━━━  1/14 [tzdata]
#     Found existing installation: typing_extensions 4.15.0━━━━━  1/14 [tzdata]
#     Uninstalling typing_extensions-4.15.0:━━━━━━━━━━━━━━━━━━━━  1/14 [tzdata]
#       Successfully uninstalled typing_extensions-4.15.0━━━━━━━━━━━  2/14 [typing_extensions]
#   Attempting uninstall: sixm━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/14 [typing_extensions]
#     Found existing installation: six 1.17.0━━━━━━━━━━━━━━━━━━━  2/14 [typing_extensions]
#     Uninstalling six-1.17.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/14 [typing_extensions]
#       Successfully uninstalled six-1.17.0━━━━━━━━━━━━━━━━━━━━━  2/14 [typing_extensions]
#   Attempting uninstall: numpy━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/14 [typing_extensions]
#     Found existing installation: numpy 2.4.4━━━━━━━━━━━━━━━━━━  2/14 [typing_extensions]
#     Uninstalling numpy-2.4.4:━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/14 [numpy]ensions]
#       Successfully uninstalled numpy-2.4.4━━━━━━━━━━━━━━━━━━━━  4/14 [numpy]
#   Attempting uninstall: idna╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/14 [numpy]
#     Found existing installation: idna 3.13━━━━━━━━━━━━━━━━━━━━  4/14 [numpy]
#     Uninstalling idna-3.13:0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/14 [numpy]
#       Successfully uninstalled idna-3.13━━━━━━━━━━━━━━━━━━━━━━  4/14 [numpy]
#   Attempting uninstall: h11╺━━━━━━━━━━━━━━━━━━━━━━━━━  5/14 [idna]
#     Found existing installation: h11 0.16.0━━━━━━━━━━━━━━━━━━━  5/14 [idna]
#     Uninstalling h11-0.16.0:━━━━━━━━━━━━━━━━━━━━━━━━━  5/14 [idna]
#       Successfully uninstalled h11-0.16.0━━━━━━━━━━━━━━━━━━━━━  5/14 [idna]
#   Attempting uninstall: certifim━━━━━━━━━━━━━━━━━━━━━━━━━  5/14 [idna]
#     Found existing installation: certifi 2026.4.22━━━━━━━━━━━━  5/14 [idna]
#     Uninstalling certifi-2026.4.22:0m━━━━━━━━━━━━━━━━━━━━━━━━━  5/14 [idna]
#       Successfully uninstalled certifi-2026.4.22━━━━━━━━━━━━━━  5/14 [idna]
#   Attempting uninstall: python-dateutil━━━━━━━━━━━━━━━━━━━━━━━  5/14 [idna]
#     Found existing installation: python-dateutil 2.9.0.post0━━  5/14 [idna]
#     Uninstalling python-dateutil-2.9.0.post0:━━━━━━━━━━━━━━━━━  5/14 [idna]
#       Successfully uninstalled python-dateutil-2.9.0.post0━━━━  5/14 [idna]
#   Attempting uninstall: httpcore━━━━━━━━━━━━━━━━━━━━━━━━━  5/14 [idna]
#     Found existing installation: httpcore 1.0.9━━━━━━━━━━━━━━━  5/14 [idna]
#     Uninstalling httpcore-1.0.9:━━━━━━━━━━━━━━━━━━━━━━━━━  5/14 [idna]
#       Successfully uninstalled httpcore-1.0.9━━━━━━━━━━━━━━━━━  5/14 [idna]
#   Attempting uninstall: anyio━━━━━━━━━━━━━━━━━━━━━━━━━  5/14 [idna]
#     Found existing installation: anyio 4.13.0━━━━━━━━━━━━━━━━━  5/14 [idna]
#     Uninstalling anyio-4.13.0:0m━━━━━━━━━━━━━━━━━━━━━━━━━  5/14 [idna]
#       Successfully uninstalled anyio-4.13.0━━━━━━━━━━━━━━━━━━━  5/14 [idna]
#   Attempting uninstall: pandas━━━━━━╸━━━━━━━━━━━ 10/14 [anyio]
#     Found existing installation: pandas 2.3.3m━━━━━━━━━━━ 10/14 [anyio]
#     Uninstalling pandas-2.3.3:━━╸━━━━━━━━━━━ 10/14 [anyio]
#       Successfully uninstalled pandas-2.3.3━━━━━━━━━━━ 10/14 [anyio]
#   Attempting uninstall: httpx━━━━━━━━━━╺━━━━━━━━ 11/14 [pandas]
#     Found existing installation: httpx 0.28.1━━━━━━━━ 11/14 [pandas]
#     Uninstalling httpx-0.28.1:━━━━━╺━━━━━━━━ 11/14 [pandas]
#       Successfully uninstalled httpx-0.28.1m╺━━━━━━━━ 11/14 [pandas]
#   Attempting uninstall: picsure━━━━╺━━━━━━━━ 11/14 [pandas]
#     Found existing installation: picsure 0.1.0━━━━━━━━ 11/14 [pandas]
#     Uninstalling picsure-0.1.0:━━━━╺━━━━━━━━ 11/14 [pandas]
#       Successfully uninstalled picsure-0.1.0╺━━━━━━━━ 11/14 [pandas]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14/14 [picsure] [pandas]
# Successfully installed anyio-4.13.0 certifi-2026.4.22 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.13 numpy-2.4.4 pandas-2.3.3 picsure-0.1.0 python-dateutil-2.9.0.post0 pytz-2026.2 six-1.17.0 typing_extensions-4.15.0 tzdata-2026.2
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import picsure
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import picsure
#
# File ~/.virtualenvs/venv/lib/python3.11/site-packages/picsure/__init__.py:11
#       9 from picsure._models.query import Query
#      10 from picsure._models.query_type import QueryType
# ---> 11 from picsure._models.session import Session
#      12 from picsure._services.connect import connect
#      13 from picsure._services.query_build import buildClauseGroup, createClause
#
# File ~/.virtualenvs/venv/lib/python3.11/site-packages/picsure/_models/session.py:5
#       1 from __future__ import annotations
#       3 from typing import TYPE_CHECKING
# ----> 5 import pandas as pd
#       7 from picsure._dev.config import DevConfig
#       8 from picsure._dev.reporting import events_to_df, stats_to_df
#
# File ~/.virtualenvs/venv/lib/python3.11/site-packages/pandas/__init__.py:37
#      30     _module = _err.name
#      31     raise ImportError(
#      32         f"C extension: {_module} not built. If you want to import "
#      33         "pandas from the source directory, you may need to run "
#      34         "'python setup.py build_ext' to build the C extensions first."
#      35     ) from _err
# ---> 37 from pandas._config import (
#      38     get_option,
#      39     set_option,
#      40     reset_option,
#      41     describe_option,
#      42     option_context,
#      43     options,
#      44 )
#      46 # let init-time option registration happen
#      47 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
#
# File ~/.virtualenvs/venv/lib/python3.11/site-packages/pandas/_config/__init__.py:20
#       1 """
#       2 pandas._config is considered explicitly upstream of everything else in pandas,
#       3 should have no intra-pandas dependencies.
#    (...)      6 are initialized.
#       7 """
#       8 __all__ = [
#       9     "config",
#      10     "detect_console_encoding",
#    (...)     18     "warn_copy_on_write",
#      19 ]
# ---> 20 from pandas._config import config
#      21 from pandas._config import dates  # pyright: ignore[reportUnusedImport]  # noqa: F401
#      22 from pandas._config.config import (
#      23     _global_config,
#      24     describe_option,
#    (...)     29     set_option,
#      30 )
#
# File ~/.virtualenvs/venv/lib/python3.11/site-packages/pandas/_config/config.py:68
#      58 from typing import (
#      59     TYPE_CHECKING,
#      60     Any,
#    (...)     64     cast,
#      65 )
#      66 import warnings
# ---> 68 from pandas._typing import (
#      69     F,
#      70     T,
#      71 )
#      72 from pandas.util._exceptions import find_stack_level
#      74 if TYPE_CHECKING:
#
# File ~/.virtualenvs/venv/lib/python3.11/site-packages/pandas/_typing.py:198
#     192 Frequency = Union[str, "BaseOffset"]
#     193 Axes = ListLike
#     195 RandomState = Union[
#     196     int,
#     197     np.ndarray,
# --> 198     np.random.Generator,
#     199     np.random.BitGenerator,
#     200     np.random.RandomState,
#     201 ]
#     203 # dtypes
#     204 NpDtype = Union[str, np.dtype, type_t[Union[str, complex, bool, object]]]
#
# File ~/.virtualenvs/venv/lib/python3.11/site-packages/numpy/__init__.py:718, in __getattr__(attr)
#     716     return dtypes
#     717 elif attr == "random":
# --> 718     import numpy.random as random
#     719     return random
#     720 elif attr == "polynomial":
#
# File ~/.virtualenvs/venv/lib/python3.11/site-packages/numpy/random/__init__.py:180
#     126 __all__ = [
#     127     'beta',
#     128     'binomial',
#    (...)    176     'zipf',
#     177 ]
#     179 # add these for module-freeze analysis (like PyInstaller)
# --> 180 from . import _bounded_integers, _common, _pickle
#     181 from ._generator import Generator, default_rng
#     182 from ._mt19937 import MT19937
#
# File ~/.virtualenvs/venv/lib/python3.11/site-packages/numpy/random/_pickle.py:7
#       5 from ._sfc64 import SFC64
#       6 from .bit_generator import BitGenerator
# ----> 7 from .mtrand import RandomState
#       9 BitGenerators = {'MT19937': MT19937,
#      10                  'PCG64': PCG64,
#      11                  'PCG64DXSM': PCG64DXSM,
#      12                  'Philox': Philox,
#      13                  'SFC64': SFC64,
#      14                  }
#      17 def __bit_generator_ctor(bit_generator: str | type[BitGenerator] = 'MT19937'):
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1138, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:1078, in _find_spec(name, path, target)
#
# File <frozen importlib._bootstrap_external>:1507, in PathFinder.find_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1479, in PathFinder._get_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1616, in FileFinder.find_spec(self, fullname, target)
#
# File <frozen importlib._bootstrap_external>:147, in _path_stat(path)
#
# KeyboardInterrupt:

# %%
token_file = "token.txt"

with open(token_file, "r") as f:
    my_token = f.read()

# %%
authorized_session = picsure.connect(
    picsure.Platform.BDC_DEV_AUTHORIZED,
    my_token
)

# %%
open_session = picsure.connect(
    picsure.Platform.BDC_DEV_OPEN
)

# %%
nhanes_open = picsure.connect(
    picsure.Platform.NHANES_OPEN
)
